# %%
import pandas as pd

df = pd.read_csv('notes.tsv',sep = '\t', low_memory=False)

# %%
print(df.at[5,'tweetId'])
print(df.at[5, 'summary'])
# print(df.columns.tolist())
# Out:
# 1537080831751102467
# Teslas purchased after 12/31/19 are not eligible for US Federal tax credits because they exceeded the initial 200K eligible cars allowed a credit. States like CA have their own programs that issue rebates or credits but many have ended as well due to higher Tesla prices. https://cleanvehiclerebate.org/en/faqs/can-i-apply-rebate-my-tesla-model-3-or-tesla-model-y

# %%
df.head(10)
# Out:
#                 noteId                            noteAuthorParticipantId  \
# 0  1783179305159200982  C784F04F26E124F4D6EC01658D8F5565005D3092741FB3...
# 1  1783181538789605871  C784F04F26E124F4D6EC01658D8F5565005D3092741FB3...
# 2  1783182562279494134  C784F04F26E124F4D6EC01658D8F5565005D3092741FB3...
# 3  1537142913737428992  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 4  1537145358521839617  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 5  1537147343715282945  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 6  1537204430730211328  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 7  1540422295029551104  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 8  1586769867381669889  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
# 9  1599066819402162177  5684B38EB58FD8BE75ABA37F0BE040EC70380B002ADF9D...
#
#    createdAtMillis              tweetId  \
# 0    1713978050878  1783159712986382830
# 1    1713978583415  1783171851818021181
# ...

# %%
import asyncio
from twscrape import API, gather
from twscrape.logger import set_log_level


api = API()  # or API("path-to.db") - default is `accounts.db`

    # ADD ACCOUNTS (for CLI usage see BELOW)
await api.pool.add_account("gartmobile", "md200300", "markdeaconu6@gmail.com", "md200300")
await api.pool.login_all()
tweet_record = []
i = 0
for tweetid in df['tweetId']:
    user_data = await api.tweet_details(tweetid)
    try:
        print(user_data.user.username, i)
    except Exception:
        print(i)
    i+=1
    tweet_record.append(user_data)

    # API USAGE

    # tweets = await gather(api.user_tweets(44196397, limit=10))
    
    # for i, tweet in enumerate(tweets, start=1):
    #     print(f"{i}. Tweet ID: {tweet.id}")
    #     print(f"   Username: {tweet.user.username}")
    #     print(f"   Text: {tweet.rawContent}\n")
# Out:
# 2025-01-12 18:10:37.429 | INFO     | twscrape.accounts_pool:add_account:110 - Account gartmobile added successfully (active=False)
# 2025-01-12 18:10:37.431 | INFO     | twscrape.accounts_pool:login_all:183 - [1/1] Logging in gartmobile - markdeaconu6@gmail.com
# 2025-01-12 18:10:38.394 | ERROR    | twscrape.accounts_pool:login:165 - Failed to login 'gartmobile': ct0 not in cookies (most likely ip ban)
# 2025-01-12 18:10:38.412 | WARNING  | twscrape.accounts_pool:get_for_queue_or_wait:297 - No active accounts. Stopping...
# 2025-01-12 18:10:38.414 | WARNING  | twscrape.accounts_pool:get_for_queue_or_wait:297 - No active accounts. Stopping...
# 2025-01-12 18:10:38.417 | WARNING  | twscrape.accounts_pool:get_for_queue_or_wait:297 - No active accounts. Stopping...
# 2025-01-12 18:10:38.419 | WARNING  | twscrape.accounts_pool:get_for_queue_or_wait:297 - No active accounts. Stopping...
# ...
